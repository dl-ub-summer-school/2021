# %% [markdown]
# <a href="https://colab.research.google.com/github/dl-ub-summer-school/2021/blob/main/Seminar_3_Logistic_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep learning UB 2021
# ## Семинар 3 -- Logistic regress-ийг машин сургалтын аргаар бодъё.

# %% [markdown]
# # Өмнөх дугаарт ....

# %% [markdown]
# ## Регресс ба ангилал
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Математикийн хэлээр
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Neural network дүрслэлээр
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
# ---
# # За семинараа эхлэе!

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import torch.nn as nn
from sklearn import datasets

# %%
# Өгөгдөлөө бэлдье. 
# 100 shirheg X, y uusgey 
# [-0.5, 0.5], [0.5, -0.5] tseguudiig  toirson random tseguud 

n_pts = 100
centers = [[-0.5, 0.5], [0.5, -0.5]]
X, y = datasets.make_blobs(n_samples=n_pts, random_state=123, centers=centers, cluster_std=0.4)

x_data = torch.Tensor(X)
y_data = torch.Tensor(y.reshape(100, 1))
print(y.shape)
# Out:
# (100,)

# %%
  plt.scatter(X[y==0, 0], X[y==0, 1])
  plt.scatter(X[y==1, 0], X[y==1, 1])
